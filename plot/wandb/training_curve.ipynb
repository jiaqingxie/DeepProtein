# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file
file_path = 'wandb_subcellular_acc.csv'
df = pd.read_csv(file_path)

# Extract relevant data and ensure numeric conversion for all models
def convert_and_interpolate(column_name):
    return pd.to_numeric(df[column_name], errors='coerce').interpolate()

# Steps for x-axis
steps = convert_and_interpolate('Step')

# Extract data for different models
accuracy_mean_cnn = convert_and_interpolate('SubCellular + CNN - Accuracy')
accuracy_min_cnn = convert_and_interpolate('SubCellular + CNN - Accuracy__MIN')
accuracy_max_cnn = convert_and_interpolate('SubCellular + CNN - Accuracy__MAX')

accuracy_mean_transformer = convert_and_interpolate('SubCellular + Transformer - Accuracy')
accuracy_min_transformer = convert_and_interpolate('SubCellular + Transformer - Accuracy__MIN')
accuracy_max_transformer = convert_and_interpolate('SubCellular + Transformer - Accuracy__MAX')

accuracy_mean_gcn = convert_and_interpolate('SubCellular + DGL_GCN - Accuracy')
accuracy_min_gcn = convert_and_interpolate('SubCellular + DGL_GCN - Accuracy__MIN')
accuracy_max_gcn = convert_and_interpolate('SubCellular + DGL_GCN - Accuracy__MAX')

accuracy_mean_cnn_rnn = convert_and_interpolate('SubCellular + CNN_RNN - Accuracy')
accuracy_min_cnn_rnn = convert_and_interpolate('SubCellular + CNN_RNN - Accuracy__MIN')
accuracy_max_cnn_rnn = convert_and_interpolate('SubCellular + CNN_RNN - Accuracy__MAX')

accuracy_mean_neuralfp = convert_and_interpolate('SubCellular + DGL_NeuralFP - Accuracy')
accuracy_min_neuralfp = convert_and_interpolate('SubCellular + DGL_NeuralFP - Accuracy__MIN')
accuracy_max_neuralfp = convert_and_interpolate('SubCellular + DGL_NeuralFP - Accuracy__MAX')

plt.figure(figsize=(6, 5))

# Set font parameters
plt.rcParams.update({'font.size': 14, 'font.family': 'Times New Roman'})

# Plot for CNN
sns.lineplot(x=steps, y=accuracy_mean_cnn, label='CNN', color='blue')
plt.fill_between(steps, accuracy_min_cnn, accuracy_max_cnn, color='blue', alpha=0.2)

# Plot for Transformer
sns.lineplot(x=steps, y=accuracy_mean_transformer, label='Transformer', color='green')
plt.fill_between(steps, accuracy_min_transformer, accuracy_max_transformer, color='green', alpha=0.2)

# Plot for DGL_GCN
sns.lineplot(x=steps, y=accuracy_mean_gcn, label='GCN', color='red')
plt.fill_between(steps, accuracy_min_gcn, accuracy_max_gcn, color='red', alpha=0.2)

# Plot for CNN_RNN
sns.lineplot(x=steps, y=accuracy_mean_cnn_rnn, label='CNN_RNN', color='purple')
plt.fill_between(steps, accuracy_min_cnn_rnn, accuracy_max_cnn_rnn, color='purple', alpha=0.2)

# Plot for NeuralFP
sns.lineplot(x=steps, y=accuracy_mean_neuralfp, label='NeuralFP', color='brown')
plt.fill_between(steps, accuracy_min_neuralfp, accuracy_max_neuralfp, color='brown', alpha=0.2)

# Adding labels and title with larger font
plt.xlabel('Step', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Training Curves (Acc.) for SubCellular', fontsize=16)
plt.legend(fontsize=14)
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig("../results/curve_subcellular_acc.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the accuracy and loss CSV files
accuracy_file_path = 'wandb_subcellular_acc.csv'
loss_file_path = 'wandb_subcellular_loss.csv'
df_acc = pd.read_csv(accuracy_file_path)
df_loss = pd.read_csv(loss_file_path)

# Function to convert and interpolate data
def convert_and_interpolate(column_name, df, target_length):
    data = pd.to_numeric(df[column_name], errors='coerce').interpolate()
    return data[:target_length]  # Ensure the data length matches the steps

# Extract steps
steps = convert_and_interpolate('Step', df_acc, len(df_acc))

# Define target length based on steps
target_length = len(steps)

# Extract accuracy data for different models
accuracy_mean_cnn = convert_and_interpolate('SubCellular + CNN - Accuracy', df_acc, target_length)
accuracy_min_cnn = convert_and_interpolate('SubCellular + CNN - Accuracy__MIN', df_acc, target_length)
accuracy_max_cnn = convert_and_interpolate('SubCellular + CNN - Accuracy__MAX', df_acc, target_length)

accuracy_mean_transformer = convert_and_interpolate('SubCellular + Transformer - Accuracy', df_acc, target_length)
accuracy_min_transformer = convert_and_interpolate('SubCellular + Transformer - Accuracy__MIN', df_acc, target_length)
accuracy_max_transformer = convert_and_interpolate('SubCellular + Transformer - Accuracy__MAX', df_acc, target_length)

accuracy_mean_gcn = convert_and_interpolate('SubCellular + DGL_GCN - Accuracy', df_acc, target_length)
accuracy_min_gcn = convert_and_interpolate('SubCellular + DGL_GCN - Accuracy__MIN', df_acc, target_length)
accuracy_max_gcn = convert_and_interpolate('SubCellular + DGL_GCN - Accuracy__MAX', df_acc, target_length)

accuracy_mean_cnn_rnn = convert_and_interpolate('SubCellular + CNN_RNN - Accuracy', df_acc, target_length)
accuracy_min_cnn_rnn = convert_and_interpolate('SubCellular + CNN_RNN - Accuracy__MIN', df_acc, target_length)
accuracy_max_cnn_rnn = convert_and_interpolate('SubCellular + CNN_RNN - Accuracy__MAX', df_acc, target_length)

accuracy_mean_neuralfp = convert_and_interpolate('SubCellular + DGL_NeuralFP - Accuracy', df_acc, target_length)
accuracy_min_neuralfp = convert_and_interpolate('SubCellular + DGL_NeuralFP - Accuracy__MIN', df_acc, target_length)
accuracy_max_neuralfp = convert_and_interpolate('SubCellular + DGL_NeuralFP - Accuracy__MAX', df_acc, target_length)

# Extract loss data for different models
loss_mean_cnn = convert_and_interpolate('SubCellular + CNN - training loss', df_loss, target_length)
loss_min_cnn = convert_and_interpolate('SubCellular + CNN - training loss__MIN', df_loss, target_length)
loss_max_cnn = convert_and_interpolate('SubCellular + CNN - training loss__MAX', df_loss, target_length)

loss_mean_transformer = convert_and_interpolate('SubCellular + Transformer - training loss', df_loss, target_length)
loss_min_transformer = convert_and_interpolate('SubCellular + Transformer - training loss__MIN', df_loss, target_length)
loss_max_transformer = convert_and_interpolate('SubCellular + Transformer - training loss__MAX', df_loss, target_length)

loss_mean_gcn = convert_and_interpolate('SubCellular + DGL_GCN - training loss', df_loss, target_length)
loss_min_gcn = convert_and_interpolate('SubCellular + DGL_GCN - training loss__MIN', df_loss, target_length)
loss_max_gcn = convert_and_interpolate('SubCellular + DGL_GCN - training loss__MAX', df_loss, target_length)

loss_mean_cnn_rnn = convert_and_interpolate('SubCellular + CNN_RNN - training loss', df_loss, target_length)
loss_min_cnn_rnn = convert_and_interpolate('SubCellular + CNN_RNN - training loss__MIN', df_loss, target_length)
loss_max_cnn_rnn = convert_and_interpolate('SubCellular + CNN_RNN - training loss__MAX', df_loss, target_length)

loss_mean_neuralfp = convert_and_interpolate('SubCellular + DGL_NeuralFP - training loss', df_loss, target_length)
loss_min_neuralfp = convert_and_interpolate('SubCellular + DGL_NeuralFP - training loss__MIN', df_loss, target_length)
loss_max_neuralfp = convert_and_interpolate('SubCellular + DGL_NeuralFP - training loss__MAX', df_loss, target_length)

# Plotting the accuracy and loss curves side by side with variance
plt.figure(figsize=(14, 6))

# Plotting accuracy curves
plt.subplot(1, 2, 1)
plt.rcParams.update({'font.size': 14, 'font.family': 'Times New Roman'})

# Plot for CNN
sns.lineplot(x=steps, y=accuracy_mean_cnn, label='CNN', color='blue')
plt.fill_between(steps, accuracy_min_cnn, accuracy_max_cnn, color='blue', alpha=0.2)

# Plot for Transformer
sns.lineplot(x=steps, y=accuracy_mean_transformer, label='Transformer', color='green')
plt.fill_between(steps, accuracy_min_transformer, accuracy_max_transformer, color='green', alpha=0.2)

# Plot for DGL_GCN
sns.lineplot(x=steps, y=accuracy_mean_gcn, label='GCN', color='red')
plt.fill_between(steps, accuracy_min_gcn, accuracy_max_gcn, color='red', alpha=0.2)

# Plot for CNN_RNN
sns.lineplot(x=steps, y=accuracy_mean_cnn_rnn, label='CNN_RNN', color='purple')
plt.fill_between(steps, accuracy_min_cnn_rnn, accuracy_max_cnn_rnn, color='purple', alpha=0.2)

# Plot for NeuralFP
sns.lineplot(x=steps, y=accuracy_mean_neuralfp, label='NeuralFP', color='brown')
plt.fill_between(steps, accuracy_min_neuralfp, accuracy_max_neuralfp, color='brown', alpha=0.2)

# Adding labels and title for accuracy
plt.xlabel('Step', fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
plt.title('Training Curves (Accuracy) for SubCellular', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

# Plotting loss curves
plt.subplot(1, 2, 2)
plt.rcParams.update({'font.size': 14, 'font.family': 'Times New Roman'})

# Plot for CNN Loss
sns.lineplot(x=steps, y=loss_mean_cnn, label='CNN', color='blue')
plt.fill_between(steps, loss_min_cnn, loss_max_cnn, color='blue', alpha=0.2)

# Plot for Transformer Loss
sns.lineplot(x=steps, y=loss_mean_transformer, label='Transformer', color='green')
plt.fill_between(steps, loss_min_transformer, loss_max_transformer, color='green', alpha=0.2)

# Plot for DGL_GCN Loss
sns.lineplot(x=steps, y=loss_mean_gcn, label='GCN', color='red')
plt.fill_between(steps, loss_min_gcn, loss_max_gcn, color='red', alpha=0.2)

# Plot for CNN_RNN Loss
sns.lineplot(x=steps, y=loss_mean_cnn_rnn, label='CNN_RNN', color='purple')
plt.fill_between(steps, loss_min_cnn_rnn, loss_max_cnn_rnn, color='purple', alpha=0.2)

# Plot for NeuralFP Loss
sns.lineplot(x=steps, y=loss_mean_neuralfp, label='NeuralFP', color='brown')
plt.fill_between(steps, loss_min_neuralfp, loss_max_neuralfp, color='brown', alpha=0.2)

# Adding labels and title for loss
plt.xlabel('Step', fontsize=18)
plt.ylabel('training loss', fontsize=18)
plt.title('Training Curves (Loss) for SubCellular', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

# Adjust layout and save the combined plot
plt.tight_layout()
plt.savefig("../results/curve_subcellular.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the accuracy and loss CSV files
accuracy_file_path = 'wandb_ppiaff_r2.csv'
loss_file_path = 'wandb_ppiaff_loss.csv'
df_acc = pd.read_csv(accuracy_file_path)
df_loss = pd.read_csv(loss_file_path)

# Function to convert and interpolate data
def convert_and_interpolate(column_name, df, target_length):
    data = pd.to_numeric(df[column_name], errors='coerce').interpolate()
    return data[:target_length]  # Ensure the data length matches the steps

# Extract steps
steps = convert_and_interpolate('Step', df_acc, len(df_acc))

# Define target length based on steps
target_length = len(steps)

# Extract accuracy data for different models
accuracy_mean_cnn = convert_and_interpolate('PPI_Affinity + CNN - R2', df_acc, target_length)
accuracy_min_cnn = convert_and_interpolate('PPI_Affinity + CNN - R2__MIN', df_acc, target_length)
accuracy_max_cnn = convert_and_interpolate('PPI_Affinity + CNN - R2__MAX', df_acc, target_length)

accuracy_mean_transformer = convert_and_interpolate('PPI_Affinity + Transformer - R2', df_acc, target_length)
accuracy_min_transformer = convert_and_interpolate('PPI_Affinity + Transformer - R2__MIN', df_acc, target_length)
accuracy_max_transformer = convert_and_interpolate('PPI_Affinity + Transformer - R2__MAX', df_acc, target_length)

accuracy_mean_gcn = convert_and_interpolate('PPI_Affinity + DGL_GAT - R2', df_acc, target_length)
accuracy_min_gcn = convert_and_interpolate('PPI_Affinity + DGL_GAT - R2__MIN', df_acc, target_length)
accuracy_max_gcn = convert_and_interpolate('PPI_Affinity + DGL_GAT - R2__MAX', df_acc, target_length)

accuracy_mean_cnn_rnn = convert_and_interpolate('PPI_Affinity + CNN_RNN - R2', df_acc, target_length)
accuracy_min_cnn_rnn = convert_and_interpolate('PPI_Affinity + CNN_RNN - R2__MIN', df_acc, target_length)
accuracy_max_cnn_rnn = convert_and_interpolate('PPI_Affinity + CNN_RNN - R2__MAX', df_acc, target_length)

# Extract loss data for different models
loss_mean_cnn = convert_and_interpolate('PPI_Affinity + CNN - training loss', df_loss, target_length)
loss_min_cnn = convert_and_interpolate('PPI_Affinity + CNN - training loss__MIN', df_loss, target_length)
loss_max_cnn = convert_and_interpolate('PPI_Affinity + CNN - training loss__MAX', df_loss, target_length)

loss_mean_transformer = convert_and_interpolate('PPI_Affinity + Transformer - training loss', df_loss, target_length)
loss_min_transformer = convert_and_interpolate('PPI_Affinity + Transformer - training loss__MIN', df_loss, target_length)
loss_max_transformer = convert_and_interpolate('PPI_Affinity + Transformer - training loss__MAX', df_loss, target_length)

loss_mean_gcn = convert_and_interpolate('PPI_Affinity + DGL_GAT - training loss', df_loss, target_length)
loss_min_gcn = convert_and_interpolate('PPI_Affinity + DGL_GAT - training loss__MIN', df_loss, target_length)
loss_max_gcn = convert_and_interpolate('PPI_Affinity + DGL_GAT - training loss__MAX', df_loss, target_length)

loss_mean_cnn_rnn = convert_and_interpolate('PPI_Affinity + CNN_RNN - training loss', df_loss, target_length)
loss_min_cnn_rnn = convert_and_interpolate('PPI_Affinity + CNN_RNN - training loss__MIN', df_loss, target_length)
loss_max_cnn_rnn = convert_and_interpolate('PPI_Affinity + CNN_RNN - training loss__MAX', df_loss, target_length)

# Plotting the accuracy and loss curves side by side with variance
plt.figure(figsize=(14, 6))

# Plotting accuracy curves
plt.subplot(1, 2, 1)
plt.rcParams.update({'font.size': 14, 'font.family': 'Times New Roman'})

# Plot for CNN
sns.lineplot(x=steps, y=accuracy_mean_cnn, label='CNN', color='blue')
plt.fill_between(steps, accuracy_min_cnn, accuracy_max_cnn, color='blue', alpha=0.2)

# Plot for Transformer
sns.lineplot(x=steps, y=accuracy_mean_transformer, label='Transformer', color='green')
plt.fill_between(steps, accuracy_min_transformer, accuracy_max_transformer, color='green', alpha=0.2)

# Plot for DGL_GAT
sns.lineplot(x=steps, y=accuracy_mean_gcn, label='GAT', color='red')
plt.fill_between(steps, accuracy_min_gcn, accuracy_max_gcn, color='red', alpha=0.2)

# Plot for CNN_RNN
sns.lineplot(x=steps, y=accuracy_mean_cnn_rnn, label='CNN_RNN', color='purple')
plt.fill_between(steps, accuracy_min_cnn_rnn, accuracy_max_cnn_rnn, color='purple', alpha=0.2)


# Adding labels and title for accuracy
plt.xlabel('Step', fontsize=18)
plt.ylabel('R2', fontsize=18)
plt.title('Training Curves (R2) for PPI Affinity', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

# Plotting loss curves
plt.subplot(1, 2, 2)
plt.rcParams.update({'font.size': 14, 'font.family': 'Times New Roman'})

# Plot for CNN Loss
sns.lineplot(x=steps, y=loss_mean_cnn, label='CNN', color='blue')
plt.fill_between(steps, loss_min_cnn, loss_max_cnn, color='blue', alpha=0.2)

# Plot for Transformer Loss
sns.lineplot(x=steps, y=loss_mean_transformer, label='Transformer', color='green')
plt.fill_between(steps, loss_min_transformer, loss_max_transformer, color='green', alpha=0.2)

# Plot for DGL_GCN Loss
sns.lineplot(x=steps, y=loss_mean_gcn, label='GAT', color='red')
plt.fill_between(steps, loss_min_gcn, loss_max_gcn, color='red', alpha=0.2)

# Plot for CNN_RNN Loss
sns.lineplot(x=steps, y=loss_mean_cnn_rnn, label='CNN_RNN', color='purple')
plt.fill_between(steps, loss_min_cnn_rnn, loss_max_cnn_rnn, color='purple', alpha=0.2)


# Adding labels and title for loss
plt.xlabel('Step', fontsize=18)
plt.ylabel('training loss', fontsize=18)
plt.title('Training Curves (Loss) for PPI Affinity', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

# Adjust layout and save the combined plot
plt.tight_layout()
plt.savefig("../results/curve_PPI_affinity.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the accuracy and loss CSV files
accuracy_file_path = 'wandb_tap_r2.csv'
loss_file_path = 'wandb_tap_loss.csv'
df_acc = pd.read_csv(accuracy_file_path)
df_loss = pd.read_csv(loss_file_path)

# Function to convert and interpolate data
def convert_and_interpolate(column_name, df, target_length):
    data = pd.to_numeric(df[column_name], errors='coerce').interpolate()
    return data[:target_length]  # Ensure the data length matches the steps

# Extract steps
steps = convert_and_interpolate('Step', df_acc, len(df_acc))

# Define target length based on steps
target_length = len(steps)

# Extract accuracy data for different models
accuracy_mean_cnn = convert_and_interpolate('TAP + CNN - R2', df_acc, target_length)
accuracy_min_cnn = convert_and_interpolate('TAP + CNN - R2__MIN', df_acc, target_length)
accuracy_max_cnn = convert_and_interpolate('TAP + CNN - R2__MAX', df_acc, target_length)

accuracy_mean_transformer = convert_and_interpolate('TAP + Transformer - R2', df_acc, target_length)
accuracy_min_transformer = convert_and_interpolate('TAP + Transformer - R2__MIN', df_acc, target_length)
accuracy_max_transformer = convert_and_interpolate('TAP + Transformer - R2__MAX', df_acc, target_length)

accuracy_mean_gcn = convert_and_interpolate('TAP + DGL_GAT - R2', df_acc, target_length)
accuracy_min_gcn = convert_and_interpolate('TAP + DGL_GAT - R2__MIN', df_acc, target_length)
accuracy_max_gcn = convert_and_interpolate('TAP + DGL_GAT - R2__MAX', df_acc, target_length)

accuracy_mean_cnn_rnn = convert_and_interpolate('TAP + CNN_RNN - R2', df_acc, target_length)
accuracy_min_cnn_rnn = convert_and_interpolate('TAP + CNN_RNN - R2__MIN', df_acc, target_length)
accuracy_max_cnn_rnn = convert_and_interpolate('TAP + CNN_RNN - R2__MAX', df_acc, target_length)

# Extract loss data for different models
loss_mean_cnn = convert_and_interpolate('TAP + CNN - training loss', df_loss, target_length)
loss_min_cnn = convert_and_interpolate('TAP + CNN - training loss__MIN', df_loss, target_length)
loss_max_cnn = convert_and_interpolate('TAP + CNN - training loss__MAX', df_loss, target_length)

loss_mean_transformer = convert_and_interpolate('TAP + Transformer - training loss', df_loss, target_length)
loss_min_transformer = convert_and_interpolate('TAP + Transformer - training loss__MIN', df_loss, target_length)
loss_max_transformer = convert_and_interpolate('TAP + Transformer - training loss__MAX', df_loss, target_length)

loss_mean_gcn = convert_and_interpolate('TAP + DGL_GAT - training loss', df_loss, target_length)
loss_min_gcn = convert_and_interpolate('TAP + DGL_GAT - training loss__MIN', df_loss, target_length)
loss_max_gcn = convert_and_interpolate('TAP + DGL_GAT - training loss__MAX', df_loss, target_length)

loss_mean_cnn_rnn = convert_and_interpolate('TAP + CNN_RNN - training loss', df_loss, target_length)
loss_min_cnn_rnn = convert_and_interpolate('TAP + CNN_RNN - training loss__MIN', df_loss, target_length)
loss_max_cnn_rnn = convert_and_interpolate('TAP + CNN_RNN - training loss__MAX', df_loss, target_length)

# Plotting the accuracy and loss curves side by side with variance
plt.figure(figsize=(14, 6))

# Plotting accuracy curves
plt.subplot(1, 2, 1)
plt.rcParams.update({'font.size': 14, 'font.family': 'Times New Roman'})

# Plot for CNN
sns.lineplot(x=steps, y=accuracy_mean_cnn, label='CNN', color='blue')
plt.fill_between(steps, accuracy_min_cnn, accuracy_max_cnn, color='blue', alpha=0.2)

# Plot for Transformer
sns.lineplot(x=steps, y=accuracy_mean_transformer, label='Transformer', color='green')
plt.fill_between(steps, accuracy_min_transformer, accuracy_max_transformer, color='green', alpha=0.2)

# Plot for DGL_GAT
sns.lineplot(x=steps, y=accuracy_mean_gcn, label='GAT', color='red')
plt.fill_between(steps, accuracy_min_gcn, accuracy_max_gcn, color='red', alpha=0.2)

# Plot for CNN_RNN
sns.lineplot(x=steps, y=accuracy_mean_cnn_rnn, label='CNN_RNN', color='purple')
plt.fill_between(steps, accuracy_min_cnn_rnn, accuracy_max_cnn_rnn, color='purple', alpha=0.2)


# Adding labels and title for accuracy
plt.xlabel('Step', fontsize=18)
plt.ylabel('R2', fontsize=18)
plt.title('Training Curves (R2) for TAP', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

# Plotting loss curves
plt.subplot(1, 2, 2)
plt.rcParams.update({'font.size': 14, 'font.family': 'Times New Roman'})

# Plot for CNN Loss
sns.lineplot(x=steps, y=loss_mean_cnn, label='CNN', color='blue')
plt.fill_between(steps, loss_min_cnn, loss_max_cnn, color='blue', alpha=0.2)

# Plot for Transformer Loss
sns.lineplot(x=steps, y=loss_mean_transformer, label='Transformer', color='green')
plt.fill_between(steps, loss_min_transformer, loss_max_transformer, color='green', alpha=0.2)

# Plot for DGL_GCN Loss
sns.lineplot(x=steps, y=loss_mean_gcn, label='GAT', color='red')
plt.fill_between(steps, loss_min_gcn, loss_max_gcn, color='red', alpha=0.2)

# Plot for CNN_RNN Loss
sns.lineplot(x=steps, y=loss_mean_cnn_rnn, label='CNN_RNN', color='purple')
plt.fill_between(steps, loss_min_cnn_rnn, loss_max_cnn_rnn, color='purple', alpha=0.2)


# Adding labels and title for loss
plt.xlabel('Step', fontsize=18)
plt.ylabel('training loss', fontsize=18)
plt.title('Training Curves (Loss) for TAP', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

# Adjust layout and save the combined plot
plt.tight_layout()
plt.savefig("../results/curve_TAP.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the accuracy and loss CSV files
accuracy_file_path = 'wandb_sabdab_chen_r2.csv'
loss_file_path = 'wandb_sabdab_chen_loss.csv'
df_acc = pd.read_csv(accuracy_file_path)
df_loss = pd.read_csv(loss_file_path)

# Function to convert and interpolate data
def convert_and_interpolate(column_name, df, target_length):
    data = pd.to_numeric(df[column_name], errors='coerce').interpolate()
    return data[:target_length]  # Ensure the data length matches the steps

# Extract steps
steps = convert_and_interpolate('Step', df_acc, len(df_acc))

# Define target length based on steps
target_length = len(steps)

# Extract accuracy data for different models
accuracy_mean_cnn = convert_and_interpolate('SAbDab_Chen + CNN - R2', df_acc, target_length)
accuracy_min_cnn = convert_and_interpolate('SAbDab_Chen + CNN - R2__MIN', df_acc, target_length)
accuracy_max_cnn = convert_and_interpolate('SAbDab_Chen + CNN - R2__MAX', df_acc, target_length)

accuracy_mean_transformer = convert_and_interpolate('SAbDab_Chen + Transformer - R2', df_acc, target_length)
accuracy_min_transformer = convert_and_interpolate('SAbDab_Chen + Transformer - R2__MIN', df_acc, target_length)
accuracy_max_transformer = convert_and_interpolate('SAbDab_Chen + Transformer - R2__MAX', df_acc, target_length)

accuracy_mean_gcn = convert_and_interpolate('SAbDab_Chen + DGL_GCN - R2', df_acc, target_length)
accuracy_min_gcn = convert_and_interpolate('SAbDab_Chen + DGL_GCN - R2__MIN', df_acc, target_length)
accuracy_max_gcn = convert_and_interpolate('SAbDab_Chen + DGL_GCN - R2__MAX', df_acc, target_length)

accuracy_mean_cnn_rnn = convert_and_interpolate('SAbDab_Chen + CNN_RNN - R2', df_acc, target_length)
accuracy_min_cnn_rnn = convert_and_interpolate('SAbDab_Chen + CNN_RNN - R2__MIN', df_acc, target_length)
accuracy_max_cnn_rnn = convert_and_interpolate('SAbDab_Chen + CNN_RNN - R2__MAX', df_acc, target_length)

# Extract loss data for different models
loss_mean_cnn = convert_and_interpolate('SAbDab_Chen + CNN - MSE', df_loss, target_length)
loss_min_cnn = convert_and_interpolate('SAbDab_Chen + CNN - MSE__MIN', df_loss, target_length)
loss_max_cnn = convert_and_interpolate('SAbDab_Chen + CNN - MSE__MAX', df_loss, target_length)

loss_mean_transformer = convert_and_interpolate('SAbDab_Chen + Transformer - MSE', df_loss, target_length)
loss_min_transformer = convert_and_interpolate('SAbDab_Chen + Transformer - MSE__MIN', df_loss, target_length)
loss_max_transformer = convert_and_interpolate('SAbDab_Chen + Transformer - MSE__MAX', df_loss, target_length)

loss_mean_gcn = convert_and_interpolate('SAbDab_Chen + DGL_GCN - MSE', df_loss, target_length)
loss_min_gcn = convert_and_interpolate('SAbDab_Chen + DGL_GCN - MSE__MIN', df_loss, target_length)
loss_max_gcn = convert_and_interpolate('SAbDab_Chen + DGL_GCN - MSE__MAX', df_loss, target_length)

loss_mean_cnn_rnn = convert_and_interpolate('SAbDab_Chen + CNN_RNN - MSE', df_loss, target_length)
loss_min_cnn_rnn = convert_and_interpolate('SAbDab_Chen + CNN_RNN - MSE__MIN', df_loss, target_length)
loss_max_cnn_rnn = convert_and_interpolate('SAbDab_Chen + CNN_RNN - MSE__MAX', df_loss, target_length)

# Plotting the accuracy and loss curves side by side with variance
plt.figure(figsize=(14, 6))

# Plotting accuracy curves
plt.subplot(1, 2, 1)
plt.rcParams.update({'font.size': 14, 'font.family': 'Times New Roman'})

# Plot for CNN
sns.lineplot(x=steps, y=accuracy_mean_cnn, label='CNN', color='blue')
plt.fill_between(steps, accuracy_min_cnn, accuracy_max_cnn, color='blue', alpha=0.2)

# Plot for Transformer
sns.lineplot(x=steps, y=accuracy_mean_transformer, label='Transformer', color='green')
plt.fill_between(steps, accuracy_min_transformer, accuracy_max_transformer, color='green', alpha=0.2)

# Plot for DGL_GAT
sns.lineplot(x=steps, y=accuracy_mean_gcn, label='GCN', color='red')
plt.fill_between(steps, accuracy_min_gcn, accuracy_max_gcn, color='red', alpha=0.2)

# Plot for CNN_RNN
sns.lineplot(x=steps, y=accuracy_mean_cnn_rnn, label='CNN_RNN', color='purple')
plt.fill_between(steps, accuracy_min_cnn_rnn, accuracy_max_cnn_rnn, color='purple', alpha=0.2)


# Adding labels and title for accuracy
plt.xlabel('Step', fontsize=18)
plt.ylabel('R2', fontsize=18)
plt.title('Training Curves (R2) for SAbDab_Chen', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

# Plotting loss curves
plt.subplot(1, 2, 2)
plt.rcParams.update({'font.size': 14, 'font.family': 'Times New Roman'})

# Plot for CNN Loss
sns.lineplot(x=steps, y=loss_mean_cnn, label='CNN', color='blue')
plt.fill_between(steps, loss_min_cnn, loss_max_cnn, color='blue', alpha=0.2)

# Plot for Transformer Loss
sns.lineplot(x=steps, y=loss_mean_transformer, label='Transformer', color='green')
plt.fill_between(steps, loss_min_transformer, loss_max_transformer, color='green', alpha=0.2)

# Plot for DGL_GCN Loss
sns.lineplot(x=steps, y=loss_mean_gcn, label='GCN', color='red')
plt.fill_between(steps, loss_min_gcn, loss_max_gcn, color='red', alpha=0.2)

# Plot for CNN_RNN Loss
sns.lineplot(x=steps, y=loss_mean_cnn_rnn, label='CNN_RNN', color='purple')
plt.fill_between(steps, loss_min_cnn_rnn, loss_max_cnn_rnn, color='purple', alpha=0.2)


# Adding labels and title for loss
plt.xlabel('Step', fontsize=18)
plt.ylabel('training loss', fontsize=18)
plt.title('Training Curves (MSE Loss) for SAbDab_Chen', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True)

# Adjust layout and save the combined plot
plt.tight_layout()
plt.savefig("../results/curve_sabdab_Chen.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
